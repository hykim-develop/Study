# %% [markdown]
# ### 분류 문제
# - 사용할 데이터셋 : data 폴더 안에 parkinsons.csv
# - 사용할 모델 : RandomForest, 다중 퍼셉트론
# - 종속 변수 : status 컬럼 (0, 1)
# - train, test 데이터셋으로 8:2 기준으로 데이터를 학습하고 검증
# - 다중퍼셉트론의 구조는 정확도 85% 이상 (epoch의 횟수는 150회 제한)
# - RF는 gridsearchCV를 이용 (Kflod, pipeline활용)
#     - n_estimator : 50, 100, 200
#     - max_depth : None, 10, 20
#     - min_samples_split : 2, 5, 10

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
import torch
import torch.nn as nn
import torch.optim as optim

# %%
df = pd.read_csv("../data/parkinsons.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %% [markdown]
# - name : 환자의 고유번호
# - MDVP:Fo(Hz) : 평균 음높이(주파수)
# - MDVP:Fhi(Hz) : 최고의 음높이
# - MDVP:Flo(Hz) : 최저의 음높이
# - 'MDVP:Jitter(%)','MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP'
#     - 음높이의 미세한 떨림 / 불안정성 측정
# - 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5','MDVP:APQ', 'Shimmer:DDA'
#     - 음 소리 크기의 미세한 떨림 / 불안정성 측정
# - NHR : 정상적인 소리 대비 잡음의 비율
# - HNR : 잡음 대비 정상적인 소리의 비율
# - RPDE, D2 : 비선형 복잡도 측정 지수
# - DFA : 신호의 프렉탈 스케일링 지수
# - spread1, spread2, PPE : 주파수 변화의 비선형적 척도 ( 파킨슨의 큰 영향을 주는 부분 )
#
# - status : 타킷데이터 ( 0 : 정상, 1 : 비정상 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# 결측치의 개수 확인 
df.isna().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
# 상관계수 확인 ( 피쳐들 간의 상관관계를 확인하고 다중공선성의 문제를 파악 )
x = df.drop(['name', 'status'], axis=1 )
y = df['status']

# %%
x.corr(method='pearson')

# %%
# 데이터의 분할 train, test 셋으로 분할
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
y.value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
y_train.value_counts()
# Out:
# status
# 1    118
# 0     38
# Name: count, dtype: int64

# %%
# 스케일링 
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
# torch에서 사용하기 위해서 데이터의 타입을 Tensor로 변환
X_train_tensor = torch.tensor(X_train_sc, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_sc, dtype=torch.float32)
# 분류 모델에서는 종속변수의 데이터의 타입은 long 타입으로 변환 ( 예측 값에서 최대 값의 위치와 비교하여 loss 계산 )
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long)

# %%
class Clf_Model(nn.Module):
    def __init__(self, _dim):
        super(Clf_Model, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(_dim, 64), 
            nn.ReLU(), 
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 2)
        )
    def forward(self, x):
        return self.model(x)

# %%
# model = nn.Sequential(
#             nn.Linear(len(X_train.columns), 64), 
#             nn.ReLU(), 
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 2)
#         )

# %%
model = Clf_Model(X_train_tensor.shape[1])

# %%
criterion = nn.CrossEntropyLoss()
# Adam 모멘텀과 lr(보폭)을 자동으로 조절해주는데 lr 매개변수는 보폭은 최대 크기 설정
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# 모델 학습 (횟수는 150회 제한)

epochs = 150 

for epoch in range(epochs):
    # 모델을 학습 모드로 전환
    model.train()

    pred = model(X_train_tensor)
    loss = criterion(pred, y_train_tensor)

    # 기울기 초기화
    optimizer.zero_grad()
    # 역전파 계산
    loss.backward()
    # 가중치 업데이트 
    optimizer.step()
    if (epoch+1) % 30 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {round(loss.item(), 6)}")
# Out:
# Epoch [30/150], Loss: 0.039451
# Epoch [60/150], Loss: 0.00065
# Epoch [90/150], Loss: 0.000175
# Epoch [120/150], Loss: 0.000112
# Epoch [150/150], Loss: 8.2e-05

# %%
# 예측 -> 성능 평가 
model.eval()
with torch.no_grad():
    pred = model(X_test_tensor)
    # max() : (예측데이터에서 최대 값들 , 최대값들의 위치들)
    # argmax() : 최대값들의 위치들
    _, pred_labels = torch.max(pred, dim=1)

    acc = accuracy_score(y_test_tensor, pred_labels)
    print(f"Accuracy: {round(acc, 4)}")
    print(classification_report(y_test_tensor, pred_labels))
# Out:
# Accuracy: 0.9744
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.97      0.98        29
#
#     accuracy                           0.97        39
#    macro avg       0.95      0.98      0.97        39
# weighted avg       0.98      0.97      0.97        39

# %%
# RandomForestClassifier 모델 학습 및 평가

x = df.drop(['name', 'status'], axis=1 )
y = df['status']

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# 파이프라인 생성 -> 스케일링 -> 모델에 학습 
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestClassifier(random_state=42))
])
# 폴드화 
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# 파라미터 조합 
params ={
    'rf__n_estimators': [50, 100, 200],
    'rf__max_depth': [None, 10, 20],
    'rf__min_samples_split': [2, 5, 10]
}

grid_model = GridSearchCV(
    pipeline, 
    param_grid=params, 
    cv=cv, 
    n_jobs=-1, 
    scoring='accuracy'
)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('rf',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'rf__max_depth': [None, 10, 20],
#                          'rf__min_samples_split': [2, 5, 10],
#                          'rf__n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
# 최적의 파라미터를 출력 
print(grid_model.best_params_)
# Out:
# {'rf__max_depth': None, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}

# %%
# 최적의 모델을 이용하여 예측
pred = grid_model.predict(X_test)

# %%
rf_acc = accuracy_score(y_test, pred)
print(f"Random Forest Accuracy: {round(rf_acc, 4)}")
print(classification_report(y_test, pred))
# Out:
# Random Forest Accuracy: 0.9231
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39
